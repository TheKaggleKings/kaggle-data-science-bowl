# %%
import pandas as pd
import plotly.express as px

# %%
train = pd.read_pickle('../data/processed/train.pkl')
train
# Out:
#          event_id      game_session                 timestamp  \
# 4152505  27253bdc  5f9ff9bf9350a7ef  2019-07-23T02:12:17.279Z
# 4152506  27253bdc  9fc66af070776a8d  2019-07-23T02:12:53.427Z
# 4152507  27253bdc  0f1889a6816bd427  2019-07-23T02:14:27.038Z
# 4152508  27253bdc  eb119170f7cf8826  2019-07-23T02:37:51.719Z
# 3926440  27253bdc  be15f0d9402d5900  2019-07-23T14:38:25.256Z
# ...           ...               ...                       ...
# 9850786  363c86c9  55f34118ea63aa9c  2019-10-22T17:41:43.854Z
# 9850787  0a08139c  55f34118ea63aa9c  2019-10-22T17:41:43.855Z
# 9850788  e79f3763  55f34118ea63aa9c  2019-10-22T17:41:44.052Z
# 9850789  363c86c9  55f34118ea63aa9c  2019-10-22T17:41:45.786Z
# 9850790  71fe8f75  55f34118ea63aa9c  2019-10-22T17:41:45.983Z
#
#                                                 event_data installation_id  \
# 4152505             {"event_code": 2000, "event_count": 1}        5b826029
# 4152506             {"event_code": 2000, "event_count": 1}        5b826029
# 4152507             {"event_code": 2000, "event_count": 1}        5b826029
# 4152508             {"event_code": 2000, "event_count": 1}        5b826029
# 3926440             {"event_code": 2000, "event_count": 1}        55ef8814
# ...                                                    ...             ...
# 9850786  {"source":"resources","coordinates":{"x":774,"...        dbecd01e
# 9850787  {"description":"Let's put this bug back where ...        dbecd01e
# 9850788  {"bug":"grassHopper","source":"resources","coo...        dbecd01e
# 9850789  {"source":"resources","coordinates":{"x":527,"...        dbecd01e
# 9850790  {"description":"Let's put this bug back where ...        dbecd01e
#
#          event_count event_code  game_time                    title      type  \
# 4152505            1       2000          0  Welcome to Lost Lagoon!      Clip
# 4152506            1       2000          0  Tree Top City - Level 1      Clip
# 4152507            1       2000          0         Ordering Spheres      Clip
# 4152508            1       2000          0  Welcome to Lost Lagoon!      Clip
# 3926440            1       2000          0  Welcome to Lost Lagoon!      Clip
# ...              ...        ...        ...                      ...       ...
# 9850786           37       4035      33581  Bug Measurer (Activity)  Activity
# 9850787           38       3010      33581  Bug Measurer (Activity)  Activity
# 9850788           39       4030      33741  Bug Measurer (Activity)  Activity
# 9850789           40       4035      35558  Bug Measurer (Activity)  Activity
# 9850790           41       3110      35697  Bug Measurer (Activity)  Activity
#
#                world
# 4152505         NONE
# 4152506  TREETOPCITY
# 4152507  TREETOPCITY
# 4152508         NONE
# 3926440         NONE
# ...              ...
# 9850786  TREETOPCITY
# 9850787  TREETOPCITY
# 9850788  TREETOPCITY
# 9850789  TREETOPCITY
# 9850790  TREETOPCITY
#
# [11341042 rows x 11 columns]

# %%
train.query("installation_id == 'dbecd01e'")
# Out:
#          event_id      game_session                 timestamp  \
# 9849648  27253bdc  122eb2fead8c6934  2019-09-17T16:15:29.282Z
# 9849649  27253bdc  45ec8c146e61ca18  2019-09-17T16:15:58.654Z
# 9849650  d2278a3b  1067c8e520f709a7  2019-09-17T16:16:32.013Z
# 9849651  b7530680  1067c8e520f709a7  2019-09-17T16:16:33.035Z
# 9849652  67439901  1067c8e520f709a7  2019-09-17T16:16:35.461Z
# ...           ...               ...                       ...
# 9850786  363c86c9  55f34118ea63aa9c  2019-10-22T17:41:43.854Z
# 9850787  0a08139c  55f34118ea63aa9c  2019-10-22T17:41:43.855Z
# 9850788  e79f3763  55f34118ea63aa9c  2019-10-22T17:41:44.052Z
# 9850789  363c86c9  55f34118ea63aa9c  2019-10-22T17:41:45.786Z
# 9850790  71fe8f75  55f34118ea63aa9c  2019-10-22T17:41:45.983Z
#
#                                                 event_data installation_id  \
# 9849648             {"event_code": 2000, "event_count": 1}        dbecd01e
# 9849649             {"event_code": 2000, "event_count": 1}        dbecd01e
# 9849650  {"version":"1.0","round":0,"event_count":1,"ga...        dbecd01e
# 9849651  {"previous_jars":[],"round":1,"event_count":2,...        dbecd01e
# 9849652  {"description":"Hello! Today, we're making san...        dbecd01e
# ...                                                    ...             ...
# 9850786  {"source":"resources","coordinates":{"x":774,"...        dbecd01e
# 9850787  {"description":"Let's put this bug back where ...        dbecd01e
# 9850788  {"bug":"grassHopper","source":"resources","coo...        dbecd01e
# 9850789  {"source":"resources","coordinates":{"x":527,"...        dbecd01e
# 9850790  {"description":"Let's put this bug back where ...        dbecd01e
#
#          event_count event_code  game_time                     title  \
# 9849648            1       2000          0   Welcome to Lost Lagoon!
# 9849649            1       2000          0      Magma Peak - Level 1
# 9849650            1       2000          0  Bottle Filler (Activity)
# 9849651            2       2020        677  Bottle Filler (Activity)
# 9849652            3       3010       3672  Bottle Filler (Activity)
# ...              ...        ...        ...                       ...
# 9850786           37       4035      33581   Bug Measurer (Activity)
# 9850787           38       3010      33581   Bug Measurer (Activity)
# 9850788           39       4030      33741   Bug Measurer (Activity)
# 9850789           40       4035      35558   Bug Measurer (Activity)
# 9850790           41       3110      35697   Bug Measurer (Activity)
#
#              type        world
# 9849648      Clip         NONE
# 9849649      Clip    MAGMAPEAK
# 9849650  Activity    MAGMAPEAK
# 9849651  Activity    MAGMAPEAK
# 9849652  Activity    MAGMAPEAK
# ...           ...          ...
# 9850786  Activity  TREETOPCITY
# 9850787  Activity  TREETOPCITY
# 9850788  Activity  TREETOPCITY
# 9850789  Activity  TREETOPCITY
# 9850790  Activity  TREETOPCITY
#
# [1143 rows x 11 columns]

# %%
test = pd.read_pickle('../data/processed/test.pkl')
test
# Out:
#         event_id      game_session                 timestamp  \
# 184881  27253bdc  52639fb59747ca49  2019-07-24T00:04:25.361Z
# 184882  27253bdc  197f8bb606461cdc  2019-07-24T00:05:00.917Z
# 184883  27253bdc  ea7ea89e7ce39690  2019-07-24T00:05:44.404Z
# 184884  e64e2cfd  a46069b40e05632a  2019-07-24T00:07:03.549Z
# 184885  49ed92e9  a46069b40e05632a  2019-07-24T00:07:09.753Z
# ...          ...               ...                       ...
# 63797   8fee50e2  9dd2ffd1f297124d  2019-10-14T21:00:15.836Z
# 63798   070a5291  9dd2ffd1f297124d  2019-10-14T21:00:17.437Z
# 63799   f6947f54  9dd2ffd1f297124d  2019-10-14T21:00:17.444Z
# 63800   3393b68b  9dd2ffd1f297124d  2019-10-14T21:00:19.572Z
# 63801   f56e0afc  943131279f5c7719  2019-10-14T21:00:34.858Z
#
#                                                event_data installation_id  \
# 184881             {"event_code": 2000, "event_count": 1}        2ab22ff2
# 184882             {"event_code": 2000, "event_count": 1}        2ab22ff2
# 184883             {"event_code": 2000, "event_count": 1}        2ab22ff2
# 184884  {"version":"1.0","event_count":1,"game_time":0...        2ab22ff2
# 184885  {"description":"These dinosaurs are awfully th...        2ab22ff2
# ...                                                   ...             ...
# 63797   {"hat":4,"destination":"left","coordinates":{"...        101d16f5
# 63798   {"correct":true,"hats":[4,8,5],"event_count":5...        101d16f5
# 63799   {"duration":24036,"misses":0,"stage_number":2,...        101d16f5
# 63800   {"session_duration":73009,"event_count":57,"ga...        101d16f5
# 63801   {"version":"1.0","event_count":1,"game_time":0...        101d16f5
#
#         event_count event_code  game_time                       title  \
# 184881            1       2000          0     Welcome to Lost Lagoon!
# 184882            1       2000          0        Magma Peak - Level 1
# 184883            1       2000          0                Slop Problem
# 184884            1       2000          0    Watering Hole (Activity)
# 184885            2       3010       1365    Watering Hole (Activity)
# ...             ...        ...        ...                         ...
# 63797            54       4020      69275  Bird Measurer (Assessment)
# 63798            55       4100      70859  Bird Measurer (Assessment)
# 63799            56       2030      70859  Bird Measurer (Assessment)
# 63800            57       2010      73009  Bird Measurer (Assessment)
# 63801             1       2000          0  Bird Measurer (Assessment)
#
#               type        world
# 184881        Clip         NONE
# 184882        Clip    MAGMAPEAK
# 184883        Clip    MAGMAPEAK
# 184884    Activity    MAGMAPEAK
# 184885    Activity    MAGMAPEAK
# ...            ...          ...
# 63797   Assessment  TREETOPCITY
# 63798   Assessment  TREETOPCITY
# 63799   Assessment  TREETOPCITY
# 63800   Assessment  TREETOPCITY
# 63801   Assessment  TREETOPCITY
#
# [1156414 rows x 11 columns]
