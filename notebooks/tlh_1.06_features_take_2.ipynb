# %%
import pandas as pd

# %% [markdown]
# # Idea
#
# The test data is a bunch of events (which may include assessments) followed by the start of an assessement, for which we have to predict the number of attempts.
#
# The train data has a bunch of events (which may include assessments) and we have the full data for all of the assessments.
#
# This means that each observation is a collection of events up to the start of an assessment, and the labels are calculated by what happens during that assessment. So each installation id in train gives us a bunch of data points (one for each assessment).
#
# We should drop data from installation_ids which do not have assessments.

# %%
train = pd.read_pickle('../data/processed/train.pkl')
train.head(3)
# Out:
#          event_id      game_session                 timestamp  \
# 4152505  27253bdc  5f9ff9bf9350a7ef  2019-07-23T02:12:17.279Z
# 4152506  27253bdc  9fc66af070776a8d  2019-07-23T02:12:53.427Z
# 4152507  27253bdc  0f1889a6816bd427  2019-07-23T02:14:27.038Z
#
#                                      event_data installation_id  event_count  \
# 4152505  {"event_code": 2000, "event_count": 1}        5b826029            1
# 4152506  {"event_code": 2000, "event_count": 1}        5b826029            1
# 4152507  {"event_code": 2000, "event_count": 1}        5b826029            1
#
#         event_code  game_time                    title  type        world
# 4152505       2000          0  Welcome to Lost Lagoon!  Clip         NONE
# 4152506       2000          0  Tree Top City - Level 1  Clip  TREETOPCITY
# 4152507       2000          0         Ordering Spheres  Clip  TREETOPCITY

# %% [markdown]
# We want to be able to recreate this information ourselves... this is because we're eventually going to have to calculate it for stuff in the test data.

# %%
labels = pd.read_csv('../data/raw/train_labels.csv')
labels.query("installation_id == '0006a69f'")
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
labels.query("game_session == 'a9ef3ecb3d1acc6a'")
# Out:
#        game_session installation_id                       title  num_correct  \
# 4  a9ef3ecb3d1acc6a        0006a69f  Bird Measurer (Assessment)            1
#
#    num_incorrect  accuracy  accuracy_group
# 4              0       1.0               3

# %% [markdown]
# For all assessments except bird measurer, attempts are captured with code 4100. Bird measurer uses 4110. The corresponding event_data contains one of
#
# - "correct":true
# - "correct":false
#
# to indicate whether the attempt was successful.
#
# However, Bird measurer also has "correct":true and stuff in code 4100 so we must remove it.
#
# Below is an example of all attempts by one particular installation. Pre-calculated labels for it are shown above.

# %%
train.query("installation_id == '0006a69f' and type == 'Assessment' and event_code in [4100, 4110]")
# Out:
#       event_id      game_session                 timestamp  \
# 2228  25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 2709  17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 2715  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 2720  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 2725  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
# 2730  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:13.951Z
# 2733  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:17.407Z
# 2738  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:21.390Z
# 2743  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:26.296Z
# 2750  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:32.187Z
# 2756  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:38.140Z
# 2765  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:49.155Z
# 2797  25fa8af4  6bdf9623adc94d89  2019-08-06T05:38:08.036Z
# 3725  25fa8af4  9501794defd84e4d  2019-08-06T20:35:12.290Z
# 3734  25fa8af4  9501794defd84e4d  2019-08-06T20:35:16.846Z
# 4137  17113b36  a9ef3ecb3d1acc6a  2019-08-06T20:50:12.115Z
# 4153  070a5291  a9ef3ecb3d1acc6a  2019-08-06T20:50:33.283Z
#
#                                              event_data installation_id  \
# 2228  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 2709  {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 2715  {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# 2720  {"correct":false,"caterpillars":[11,8,5],"even...        0006a69f
# 2725  {"correct":false,"caterpillars":[11,8,7],"even...        0006a69f
# 2730  {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 2733  {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 2738  {"correct":false,"caterpillars":[11,8,2],"even...        0006a69f
# 2743  {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# 2750  {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# 2756  {"correct":false,"caterpillars":[5,8,1],"event...        0006a69f
# 2765  {"correct":false,"caterpillars":[5,8,6],"event...        0006a69f
# 2797  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 3725  {"correct":false,"stumps":[3,2,5],"event_count...        0006a69f
# 3734  {"correct":true,"stumps":[2,3,5],"event_count"...        0006a69f
# 4137  {"correct":true,"caterpillars":[4,8,5],"event_...        0006a69f
# 4153  {"correct":true,"hats":[4,8,5],"event_count":3...        0006a69f
#
#       event_count event_code  game_time                         title  \
# 2228           44       4100      31011  Mushroom Sorter (Assessment)
# 2709           29       4110      35771    Bird Measurer (Assessment)
# 2715           35       4110      42805    Bird Measurer (Assessment)
# 2720           40       4110      47388    Bird Measurer (Assessment)
# 2725           45       4110      50605    Bird Measurer (Assessment)
# 2730           50       4110      54822    Bird Measurer (Assessment)
# 2733           53       4110      58280    Bird Measurer (Assessment)
# 2738           58       4110      62256    Bird Measurer (Assessment)
# 2743           63       4110      67164    Bird Measurer (Assessment)
# 2750           70       4110      73056    Bird Measurer (Assessment)
# 2756           76       4110      79006    Bird Measurer (Assessment)
# 2765           85       4110      90032    Bird Measurer (Assessment)
# 2797           30       4100      18026  Mushroom Sorter (Assessment)
# 3725           29       4100      18484  Mushroom Sorter (Assessment)
# 3734           38       4100      23043  Mushroom Sorter (Assessment)
# 4137           14       4110      13050    Bird Measurer (Assessment)
# 4153           30       4100      34209    Bird Measurer (Assessment)
#
#             type        world  attempt correct
# 2228  Assessment  TREETOPCITY     True    True
# 2709  Assessment  TREETOPCITY     True   False
# 2715  Assessment  TREETOPCITY     True   False
# 2720  Assessment  TREETOPCITY     True   False
# 2725  Assessment  TREETOPCITY     True   False
# 2730  Assessment  TREETOPCITY     True   False
# 2733  Assessment  TREETOPCITY     True   False
# 2738  Assessment  TREETOPCITY     True   False
# 2743  Assessment  TREETOPCITY     True   False
# 2750  Assessment  TREETOPCITY     True   False
# 2756  Assessment  TREETOPCITY     True   False
# 2765  Assessment  TREETOPCITY     True   False
# 2797  Assessment  TREETOPCITY     True    True
# 3725  Assessment  TREETOPCITY     True   False
# 3734  Assessment  TREETOPCITY     True    True
# 4137  Assessment  TREETOPCITY     True    True
# 4153  Assessment  TREETOPCITY    False     NaN

# %% [markdown]
# Add binary column specifying whether event is an attempt or not

# %%
train['attempt'] = train.type == "Assessment" & ((train.event_code == 4100) & (train.title != 'Bird Measurer (Assessment)') | ((train.event_code == 4110) & (train.title == 'Bird Measurer (Assessment)')))
train.head(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/kaggle/kaggle-data-science-bowl/.venv/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# ~/kaggle/kaggle-data-science-bowl/.venv/lib/python3.7/site-packages/pandas/core/ops/roperator.py in rand_(left, right)
#      52 def rand_(left, right):
# ---> 53     return operator.and_(right, left)
#      54
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/kaggle/kaggle-data-science-bowl/.venv/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1268                 try:
# -> 1269                     result = libops.scalar_binop(x, y, op)
#    1270                 except (
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_binop()
#
# ValueError: Does not understand character buffer dtype format string ('?')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a2303bae6ea6> in <module>
# ----> 1 train['attempt'] = train.type == "Assessment" & ((train.event_code == 4100) & (train.title != 'Bird Measurer (Assessment)') | ((train.event_code == 4110) & (train.title == 'Bird Measurer (Assessment)')))
#       2 train.head(2)
#
# ~/kaggle/kaggle-data-science-bowl/.venv/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#    1319         #   integer dtypes.  Otherwise these are boolean ops
#    1320         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# -> 1321         res_values = na_op(self.values, ovalues)
#    1322         unfilled = self._constructor(res_values, index=self.index, name=res_name)
#    1323         filled = filler(unfilled)
#
# ~/kaggle/kaggle-data-science-bowl/.venv/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1278                         "cannot compare a dtyped [{dtype}] array "
#    1279                         "with a scalar of type [{typ}]".format(
# -> 1280                             dtype=x.dtype, typ=type(y).__name__
#    1281                         )
#    1282                     )
#
# TypeError: cannot compare a dtyped [bool] array with a scalar of type [bool]

# %% [markdown]
# Add binary column specifying whether event is correct. True means success, false means fail, and NaN on all other rows.

# %%
train.loc[train.attempt, 'correct'] = train.loc[train.attempt].event_data.str.contains('"correct":true')
train
# Out:
#          event_id      game_session                 timestamp  \
# 4152505  27253bdc  5f9ff9bf9350a7ef  2019-07-23T02:12:17.279Z
# 4152506  27253bdc  9fc66af070776a8d  2019-07-23T02:12:53.427Z
# 4152507  27253bdc  0f1889a6816bd427  2019-07-23T02:14:27.038Z
# 4152508  27253bdc  eb119170f7cf8826  2019-07-23T02:37:51.719Z
# 3926440  27253bdc  be15f0d9402d5900  2019-07-23T14:38:25.256Z
# ...           ...               ...                       ...
# 9850786  363c86c9  55f34118ea63aa9c  2019-10-22T17:41:43.854Z
# 9850787  0a08139c  55f34118ea63aa9c  2019-10-22T17:41:43.855Z
# 9850788  e79f3763  55f34118ea63aa9c  2019-10-22T17:41:44.052Z
# 9850789  363c86c9  55f34118ea63aa9c  2019-10-22T17:41:45.786Z
# 9850790  71fe8f75  55f34118ea63aa9c  2019-10-22T17:41:45.983Z
#
#                                                 event_data installation_id  \
# 4152505             {"event_code": 2000, "event_count": 1}        5b826029
# 4152506             {"event_code": 2000, "event_count": 1}        5b826029
# 4152507             {"event_code": 2000, "event_count": 1}        5b826029
# 4152508             {"event_code": 2000, "event_count": 1}        5b826029
# 3926440             {"event_code": 2000, "event_count": 1}        55ef8814
# ...                                                    ...             ...
# 9850786  {"source":"resources","coordinates":{"x":774,"...        dbecd01e
# 9850787  {"description":"Let's put this bug back where ...        dbecd01e
# 9850788  {"bug":"grassHopper","source":"resources","coo...        dbecd01e
# 9850789  {"source":"resources","coordinates":{"x":527,"...        dbecd01e
# 9850790  {"description":"Let's put this bug back where ...        dbecd01e
#
#          event_count event_code  game_time                    title      type  \
# 4152505            1       2000          0  Welcome to Lost Lagoon!      Clip
# 4152506            1       2000          0  Tree Top City - Level 1      Clip
# 4152507            1       2000          0         Ordering Spheres      Clip
# 4152508            1       2000          0  Welcome to Lost Lagoon!      Clip
# 3926440            1       2000          0  Welcome to Lost Lagoon!      Clip
# ...              ...        ...        ...                      ...       ...
# 9850786           37       4035      33581  Bug Measurer (Activity)  Activity
# 9850787           38       3010      33581  Bug Measurer (Activity)  Activity
# 9850788           39       4030      33741  Bug Measurer (Activity)  Activity
# 9850789           40       4035      35558  Bug Measurer (Activity)  Activity
# 9850790           41       3110      35697  Bug Measurer (Activity)  Activity
#
#                world  attempt correct
# 4152505         NONE    False     NaN
# 4152506  TREETOPCITY    False     NaN
# 4152507  TREETOPCITY    False     NaN
# 4152508         NONE    False     NaN
# 3926440         NONE    False     NaN
# ...              ...      ...     ...
# 9850786  TREETOPCITY    False     NaN
# 9850787  TREETOPCITY    False     NaN
# 9850788  TREETOPCITY    False     NaN
# 9850789  TREETOPCITY    False     NaN
# 9850790  TREETOPCITY    False     NaN
#
# [11341042 rows x 13 columns]

# %%
train.query("installation_id == '0006a69f' and attempt")
# Out:
#       event_id      game_session                 timestamp  \
# 2228  25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 2308  14de4c5d  80d34a30c2998653  2019-08-06T05:24:50.323Z
# 2335  14de4c5d  80d34a30c2998653  2019-08-06T05:25:11.292Z
# 2375  14de4c5d  80d34a30c2998653  2019-08-06T05:25:37.207Z
# 2409  14de4c5d  80d34a30c2998653  2019-08-06T05:26:01.055Z
# 2709  17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 2715  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 2720  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 2725  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
# 2730  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:13.951Z
# 2733  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:17.407Z
# 2738  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:21.390Z
# 2743  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:26.296Z
# 2750  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:32.187Z
# 2756  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:38.140Z
# 2765  17113b36  77b8ee947eb84b4e  2019-08-06T05:36:49.155Z
# 2797  25fa8af4  6bdf9623adc94d89  2019-08-06T05:38:08.036Z
# 3725  25fa8af4  9501794defd84e4d  2019-08-06T20:35:12.290Z
# 3734  25fa8af4  9501794defd84e4d  2019-08-06T20:35:16.846Z
# 3773  14de4c5d  8043825259dc7ddd  2019-08-06T20:36:23.582Z
# 3809  14de4c5d  8043825259dc7ddd  2019-08-06T20:36:54.289Z
# 3842  14de4c5d  8043825259dc7ddd  2019-08-06T20:37:27.005Z
# 3850  14de4c5d  8043825259dc7ddd  2019-08-06T20:37:52.614Z
# 4137  17113b36  a9ef3ecb3d1acc6a  2019-08-06T20:50:12.115Z
#
#                                              event_data installation_id  \
# 2228  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 2308  {"distance":10,"target_distances":[5,6,7,8,9,1...        0006a69f
# 2335  {"distance":9,"target_distances":[5,6,7],"corr...        0006a69f
# 2375  {"distance":3,"target_distances":[5,6,7],"corr...        0006a69f
# 2409  {"distance":8,"target_distances":[5,6,7],"corr...        0006a69f
# 2709  {"correct":false,"caterpillars":[11,8,3],"even...        0006a69f
# 2715  {"correct":false,"caterpillars":[11,8,11],"eve...        0006a69f
# 2720  {"correct":false,"caterpillars":[11,8,5],"even...        0006a69f
# 2725  {"correct":false,"caterpillars":[11,8,7],"even...        0006a69f
# 2730  {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 2733  {"correct":false,"caterpillars":[11,8,4],"even...        0006a69f
# 2738  {"correct":false,"caterpillars":[11,8,2],"even...        0006a69f
# 2743  {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# 2750  {"correct":false,"caterpillars":[11,8,1],"even...        0006a69f
# 2756  {"correct":false,"caterpillars":[5,8,1],"event...        0006a69f
# 2765  {"correct":false,"caterpillars":[5,8,6],"event...        0006a69f
# 2797  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 3725  {"correct":false,"stumps":[3,2,5],"event_count...        0006a69f
# 3734  {"correct":true,"stumps":[2,3,5],"event_count"...        0006a69f
# 3773  {"distance":10,"target_distances":[6,7,8,9,10]...        0006a69f
# 3809  {"distance":9,"target_distances":[4,5,6,7,8,9,...        0006a69f
# 3842  {"distance":10,"target_distances":[1,2,3],"cor...        0006a69f
# 3850  {"distance":4,"target_distances":[1,2,3],"corr...        0006a69f
# 4137  {"correct":true,"caterpillars":[4,8,5],"event_...        0006a69f
#
#       event_count event_code  game_time                         title  \
# 2228           44       4100      31011  Mushroom Sorter (Assessment)
# 2308           76       4100     114370                      Air Show
# 2335          103       4100     135341                      Air Show
# 2375          143       4100     161258                      Air Show
# 2409          177       4100     185103                      Air Show
# 2709           29       4110      35771    Bird Measurer (Assessment)
# 2715           35       4110      42805    Bird Measurer (Assessment)
# 2720           40       4110      47388    Bird Measurer (Assessment)
# 2725           45       4110      50605    Bird Measurer (Assessment)
# 2730           50       4110      54822    Bird Measurer (Assessment)
# 2733           53       4110      58280    Bird Measurer (Assessment)
# 2738           58       4110      62256    Bird Measurer (Assessment)
# 2743           63       4110      67164    Bird Measurer (Assessment)
# 2750           70       4110      73056    Bird Measurer (Assessment)
# 2756           76       4110      79006    Bird Measurer (Assessment)
# 2765           85       4110      90032    Bird Measurer (Assessment)
# 2797           30       4100      18026  Mushroom Sorter (Assessment)
# 3725           29       4100      18484  Mushroom Sorter (Assessment)
# 3734           38       4100      23043  Mushroom Sorter (Assessment)
# 3773           35       4100      46494                      Air Show
# 3809           71       4100      77194                      Air Show
# 3842          104       4100     109896                      Air Show
# 3850          112       4100     135531                      Air Show
# 4137           14       4110      13050    Bird Measurer (Assessment)
#
#             type        world  attempt correct
# 2228  Assessment  TREETOPCITY     True    True
# 2308        Game  TREETOPCITY     True    True
# 2335        Game  TREETOPCITY     True   False
# 2375        Game  TREETOPCITY     True   False
# 2409        Game  TREETOPCITY     True   False
# 2709  Assessment  TREETOPCITY     True   False
# 2715  Assessment  TREETOPCITY     True   False
# 2720  Assessment  TREETOPCITY     True   False
# 2725  Assessment  TREETOPCITY     True   False
# 2730  Assessment  TREETOPCITY     True   False
# 2733  Assessment  TREETOPCITY     True   False
# 2738  Assessment  TREETOPCITY     True   False
# 2743  Assessment  TREETOPCITY     True   False
# 2750  Assessment  TREETOPCITY     True   False
# 2756  Assessment  TREETOPCITY     True   False
# 2765  Assessment  TREETOPCITY     True   False
# 2797  Assessment  TREETOPCITY     True    True
# 3725  Assessment  TREETOPCITY     True   False
# 3734  Assessment  TREETOPCITY     True    True
# 3773        Game  TREETOPCITY     True    True
# 3809        Game  TREETOPCITY     True    True
# 3842        Game  TREETOPCITY     True   False
# 3850        Game  TREETOPCITY     True   False
# 4137  Assessment  TREETOPCITY     True    True
