# %%
import sys
sys.path.extend(['/home/timothy/kaggle/kaggle-data-science-bowl'])

# %%
import pandas as pd
from src.models.qwk import qwk3

# %%
a = [0,2,3]
b = [0,1,1]

qwk3(b, a, 3)
# Out:
# 0.4

# %%
df = pd.read_pickle('../data/processed/features.pkl')
df
# Out:
#       installation_id  12 Monkeys  Air Show  All Star Sorting  Balancing Act  \
# 0            0006a69f        True      True              True          False
# 1            0006a69f        True      True              True          False
# 2            0006a69f        True      True              True          False
# 3            0006a69f        True      True              True          False
# 4            0006a69f        True      True              True          False
# ...               ...         ...       ...               ...            ...
# 17685        ffc90c32        True      True              True           True
# 17686        ffd2871d       False     False             False           True
# 17687        ffeb0b1b       False     False             False          False
# 17688        ffeb0b1b       False     False             False          False
# 17689        ffeb0b1b       False     False             False          False
#
# ...

# %%
test = pd.read_pickle('../data/processed/test_features.pkl')
test
# Out:
#       installation_id  12 Monkeys  Air Show  All Star Sorting  Balancing Act  \
# 0            0006a69f        True      True              True          False
# 1            0006a69f        True      True              True          False
# 2            0006a69f        True      True              True          False
# 3            0006a69f        True      True              True          False
# 4            0006a69f        True      True              True          False
# ...               ...         ...       ...               ...            ...
# 17685        ffc90c32        True      True              True           True
# 17686        ffd2871d       False     False             False           True
# 17687        ffeb0b1b       False     False             False          False
# 17688        ffeb0b1b       False     False             False          False
# 17689        ffeb0b1b       False     False             False          False
#
# ...

# %%
df1 = pd.read_pickle('../data/processed/memory_optimized_data.pkl')
df1.memory_usage()
# Out:
# Index                   128
# event_id           90728336
# game_session       90728336
# timestamp          90728336
# event_data         90728336
# installation_id    90728336
# event_count        90728336
# event_code         11341378
# game_time          90728336
# title              11341394
# type               90728336
# world              11341074
# dtype: int64

# %%
df2 = pd.read_pickle('../data/processed/train.pkl')
df2.memory_usage()
# Out:
# Index              90728336
# event_id           22685156
# game_session       47790720
# timestamp          90728336
# event_data         90728336
# installation_id    22818084
# event_count        22682084
# event_code         11341378
# game_time          45364168
# title              11341394
# type               11341074
# world              11341074
# dtype: int64
