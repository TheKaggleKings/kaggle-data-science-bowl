# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/processed/memory_optimized_data.pkl')
df
# Out:
#           event_id      game_session                        timestamp  \
# 0         27253bdc  45bb1e1b6b50c07b 2019-09-06 17:53:46.937000+00:00
# 1         27253bdc  17eeb7f223665f53 2019-09-06 17:54:17.519000+00:00
# 2         77261ab5  0848ef14a8dc6892 2019-09-06 17:54:56.302000+00:00
# 3         b2dba42b  0848ef14a8dc6892 2019-09-06 17:54:56.387000+00:00
# 4         1bb5fbdb  0848ef14a8dc6892 2019-09-06 17:55:03.253000+00:00
# ...            ...               ...                              ...
# 11341037  ab3136ba  c09b94eebfdf50a6 2019-10-10 15:11:15.584000+00:00
# 11341038  27253bdc  6ad8ab25003ef1b0 2019-10-10 15:12:17.364000+00:00
# 11341039  27253bdc  71904dca23b982c6 2019-10-10 15:13:04.713000+00:00
# 11341040  27253bdc  2267b18f069e875a 2019-10-10 15:13:54.545000+00:00
# 11341041  27253bdc  f31950f549d7c242 2019-10-10 15:15:12.483000+00:00
#
#                                                  event_data installation_id  \
# ...

# %%
df1 = df[['title', 'installation_id']].drop_duplicates()
df1
# Out:
#                                   title installation_id
# 0               Welcome to Lost Lagoon!        0001e90f
# 1                  Magma Peak - Level 1        0001e90f
# 2         Sandcastle Builder (Activity)        0001e90f
# 362                         Scrub-A-Dub        0001e90f
# 1103               Magma Peak - Level 2        0001e90f
# ...                                 ...             ...
# 11340970        Tree Top City - Level 3        fffc0583
# 11340971           Magma Peak - Level 2        fffc0583
# 11340972                      Dino Dive        fffc0583
# 11341038        Crystal Caves - Level 2        fffc0583
# 11341039        Crystal Caves - Level 3        fffc0583
#
# [159732 rows x 2 columns]

# %%
df1['temp'] = True
df1
# Out:
#                                   title installation_id  temp
# 0               Welcome to Lost Lagoon!        0001e90f  True
# 1                  Magma Peak - Level 1        0001e90f  True
# 2         Sandcastle Builder (Activity)        0001e90f  True
# 362                         Scrub-A-Dub        0001e90f  True
# 1103               Magma Peak - Level 2        0001e90f  True
# ...                                 ...             ...   ...
# 11340970        Tree Top City - Level 3        fffc0583  True
# 11340971           Magma Peak - Level 2        fffc0583  True
# 11340972                      Dino Dive        fffc0583  True
# 11341038        Crystal Caves - Level 2        fffc0583  True
# 11341039        Crystal Caves - Level 3        fffc0583  True
#
# [159732 rows x 3 columns]

# %%
df1.pivot(columns = 'title', values = 'temp', index = 'installation_id').fillna(False)
# Out:
# title            12 Monkeys  Air Show  All Star Sorting  Balancing Act  \
# installation_id
# 0001e90f              False     False             False          False
# 000447c4              False     False             False          False
# 0006a69f               True      True              True          False
# 0006c192               True     False             False           True
# 0009a5a9              False     False             False          False
# ...                     ...       ...               ...            ...
# fff64664              False     False             False           True
# fff70c1e              False     False             False          False
# fff744ce              False     False             False          False
# fff944d5              False     False             False          False
# fffc0583               True     False              True          False
#
# title            Bird Measurer (Assessment)  Bottle Filler (Activity)  \
# installation_id
# ...
