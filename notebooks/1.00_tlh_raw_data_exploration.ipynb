# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Look at raw data

# %%
test = pd.read_csv('../data/raw/test.csv')
test.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  0ea9ecc81a565215  2019-09-10T16:50:24.910Z
# 1  27253bdc  c1ea43d8b8261d27  2019-09-10T16:50:55.503Z
# 2  27253bdc  7ed86c6b72e725e2  2019-09-10T16:51:51.805Z
# 3  27253bdc  7e516ace50e7fe67  2019-09-10T16:53:12.825Z
# 4  7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
#
#                                                                     event_data  \
# 0  {"event_code": 2000, "event_count": 1}
# 1  {"event_code": 2000, "event_count": 1}
# 2  {"event_code": 2000, "event_count": 1}
# 3  {"event_code": 2000, "event_count": 1}
# 4  {"version":"1.0","round":0,"event_count":1,"game_time":0,"event_code":2000}
#
#   installation_id  event_count  event_code  game_time  \
# 0  00abaee7        1            2000        0
# 1  00abaee7        1            2000        0
# 2  00abaee7        1            2000        0
# 3  00abaee7        1            2000        0
# 4  00abaee7        1            2000        0
#
# ...

# %%
train_sample = pd.read_csv('../data/raw/train.csv', nrows=500)
train_sample.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                                                                                                                                                                                                                                                                                  event_data  \
# 0  {"event_code": 2000, "event_count": 1}
# 1  {"event_code": 2000, "event_count": 1}
# 2  {"version":"1.0","event_count":1,"game_time":0,"event_code":2000}
# ...

# %%
labels = pd.read_csv('../data/raw/train_labels.csv')
labels.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89  0006a69f        Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e  0006a69f        Bird Measurer (Assessment)
# 2  901acc108f55a5a1  0006a69f        Mushroom Sorter (Assessment)
# 3  9501794defd84e4d  0006a69f        Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a  0006a69f        Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0  1            0              1.0       3
# 1  0            11             0.0       0
# 2  1            0              1.0       3
# 3  1            1              0.5       2
# 4  1            0              1.0       3

# %%
sample = pd.read_csv('../data/raw/sample_submission.csv')
sample.head()
# Out:
#   installation_id  accuracy_group
# 0  00abaee7        3
# 1  01242218        3
# 2  017c5718        3
# 3  01a44906        3
# 4  01bc6cb6        3

# %%
specs = pd.read_csv('../data/raw/specs.csv')
specs
# Out:
#      event_id  \
# 0    2b9272f4
# 1    df4fe8b6
# 2    3babcb9b
# 3    7f0836bf
# 4    ab3136ba
# ..        ...
# 381  29f54413
# 382  06372577
# 383  2a444e03
# 384  9e6b7fb5
# 385  d3640339
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     info  \
# ...

# %%
train_ls = pd.read_pickle('../data/processed/memory_optimized_data.pkl')
train_ls
# Out:
#           event_id      game_session                        timestamp  \
# 0         27253bdc  45bb1e1b6b50c07b 2019-09-06 17:53:46.937000+00:00
# 1         27253bdc  17eeb7f223665f53 2019-09-06 17:54:17.519000+00:00
# 2         77261ab5  0848ef14a8dc6892 2019-09-06 17:54:56.302000+00:00
# 3         b2dba42b  0848ef14a8dc6892 2019-09-06 17:54:56.387000+00:00
# 4         1bb5fbdb  0848ef14a8dc6892 2019-09-06 17:55:03.253000+00:00
# ...            ...               ...                              ...
# 11341037  ab3136ba  c09b94eebfdf50a6 2019-10-10 15:11:15.584000+00:00
# 11341038  27253bdc  6ad8ab25003ef1b0 2019-10-10 15:12:17.364000+00:00
# 11341039  27253bdc  71904dca23b982c6 2019-10-10 15:13:04.713000+00:00
# 11341040  27253bdc  2267b18f069e875a 2019-10-10 15:13:54.545000+00:00
# 11341041  27253bdc  f31950f549d7c242 2019-10-10 15:15:12.483000+00:00
#
# ...

# %%
train_ls.reset_index(drop=True).memory_usage() / 1024 / 1024
# Out:
# Index              0.000122
# event_id           86.525284
# game_session       86.525284
# timestamp          86.525284
# event_data         86.525284
# installation_id    86.525284
# event_count        86.525284
# event_code         10.817202
# game_time          86.525284
# title              10.817217
# type               86.525284
# world              10.815844
# dtype: float64

# %%
train_ls.dtypes
# Out:
# event_id           object
# game_session       object
# timestamp          datetime64[ns, UTC]
# event_data         object
# installation_id    object
# event_count        int64
# event_code         category
# game_time          int64
# title              category
# type               object
# world              category
# dtype: object

# %%
pd.to_numeric(train_ls.event_count, downcast = 'integer')
# Out:
# 0           1
# 1           1
# 2           1
# 3           2
# 4           3
#            ..
# 11341037    66
# 11341038    1
# 11341039    1
# 11341040    1
# 11341041    1
# Name: event_count, Length: 11341042, dtype: int16

# %%
train_ls.type.unique()
# Out:
# array(['Clip', 'Activity', 'Game', 'Assessment'], dtype=object)

# %%
specs
# Out:
#      event_id  \
# 0    2b9272f4
# 1    df4fe8b6
# 2    3babcb9b
# 3    7f0836bf
# 4    ab3136ba
# ..        ...
# 381  29f54413
# 382  06372577
# 383  2a444e03
# 384  9e6b7fb5
# 385  d3640339
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     info  \
# ...

# %%
train_ls.query("world == 'MAGMAPEAK' and type == 'Assessment' and installation_id == '0006c192'").sort_values('timestamp')
# Out:
#       event_id      game_session                        timestamp  \
# 6881  90d848e0  197a373a77101924 2019-09-14 15:35:41.747000+00:00
# 6882  532a2afb  197a373a77101924 2019-09-14 15:35:42.114000+00:00
# 6883  923afab1  197a373a77101924 2019-09-14 15:35:42.114000+00:00
# 6884  3ee399c3  197a373a77101924 2019-09-14 15:35:44.808000+00:00
# 6885  37ee8496  197a373a77101924 2019-09-14 15:35:45.335000+00:00
# 6886  30614231  197a373a77101924 2019-09-14 15:35:46.051000+00:00
# 6887  2dcad279  197a373a77101924 2019-09-14 15:35:46.759000+00:00
# 6888  3ee399c3  197a373a77101924 2019-09-14 15:35:47.278000+00:00
# 6889  37ee8496  197a373a77101924 2019-09-14 15:35:48.007000+00:00
# 6890  30614231  197a373a77101924 2019-09-14 15:35:48.368000+00:00
# 6891  37ee8496  197a373a77101924 2019-09-14 15:35:49.155000+00:00
# 6892  30614231  197a373a77101924 2019-09-14 15:35:49.467000+00:00
# 6893  923afab1  197a373a77101924 2019-09-14 15:35:49.473000+00:00
# ...

# %%
labels.query("installation_id == '0006c192'")
# Out:
#        game_session installation_id                         title  \
# 5  197a373a77101924  0006c192        Cauldron Filler (Assessment)
# 6  957406a905d59afd  0006c192        Bird Measurer (Assessment)
# 7  b2297d292892745a  0006c192        Mushroom Sorter (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 5  1            0              1.0       3
# 6  1            1              0.5       2
# 7  0            4              0.0       0

# %%
train_ls.query("type == 'Assessment'").title.unique()
# Out:
# [Mushroom Sorter (Assessment), Bird Measurer (Assessment), Cauldron Filler (Assessment), Cart Balancer (Assessment), Chest Sorter (Assessment)]
# Categories (5, object): [Mushroom Sorter (Assessment), Bird Measurer (Assessment), Cauldron Filler (Assessment), Cart Balancer (Assessment), Chest Sorter (Assessment)]
